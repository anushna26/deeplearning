# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,GRU,Dense
from tensorflow.keras.preprocessing import sequence

# %%
max_words = 6000
(xt,yt),(xte,yte)= imdb.load_data(num_words=max_words)

max_len =500
xt=sequence.pad_sequences(xt,maxlen=max_len)
xte=sequence.pad_sequences(xte,maxlen=max_len)

model=Sequential()
model.add(Embedding(max_words,100,input_length=max_len))
model.add(GRU(128))
model.add(Dense(1,activation='sigmoid'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
batch_size=128
epochs=10
model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/10
# 196/196 [==============================] - 52s 229ms/step - loss: 0.5074 - accuracy: 0.7404
# Epoch 2/10
# 196/196 [==============================] - 26s 134ms/step - loss: 0.3023 - accuracy: 0.8759
# Epoch 3/10
# 196/196 [==============================] - 21s 107ms/step - loss: 0.2141 - accuracy: 0.9178
# Epoch 4/10
# 196/196 [==============================] - 13s 68ms/step - loss: 0.1728 - accuracy: 0.9347
# Epoch 5/10
# 196/196 [==============================] - 10s 53ms/step - loss: 0.1313 - accuracy: 0.9540
# Epoch 6/10
# 196/196 [==============================] - 11s 58ms/step - loss: 0.1216 - accuracy: 0.9568
# Epoch 7/10
# 196/196 [==============================] - 8s 42ms/step - loss: 0.0838 - accuracy: 0.9713
# Epoch 8/10
# 196/196 [==============================] - 10s 48ms/step - loss: 0.0620 - accuracy: 0.9800
# Epoch 9/10
# 196/196 [==============================] - 8s 41ms/step - loss: 0.0575 - accuracy: 0.9804
# Epoch 10/10
# 196/196 [==============================] - 7s 37ms/step - loss: 0.0461 - accuracy: 0.9852

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 12ms/step - loss: 0.6111 - accuracy: 0.8648
# accuracy: 0.864799976348877
# loss: 0.61110520362854

# %%
history=model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/10
# 196/196 [==============================] - 9s 44ms/step - loss: 0.0618 - accuracy: 0.9789
# Epoch 2/10
# 196/196 [==============================] - 8s 42ms/step - loss: 0.0246 - accuracy: 0.9931
# Epoch 3/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.0230 - accuracy: 0.9933
# Epoch 4/10
# 196/196 [==============================] - 7s 37ms/step - loss: 0.0266 - accuracy: 0.9912
# Epoch 5/10
# 196/196 [==============================] - 7s 35ms/step - loss: 0.0178 - accuracy: 0.9951
# Epoch 6/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.0082 - accuracy: 0.9983
# Epoch 7/10
# 196/196 [==============================] - 7s 36ms/step - loss: 0.0157 - accuracy: 0.9956
# Epoch 8/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.0268 - accuracy: 0.9912
# Epoch 9/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.0151 - accuracy: 0.9960
# Epoch 10/10
# 196/196 [==============================] - 7s 35ms/step - loss: 0.0177 - accuracy: 0.9946

# %%
train_loss1 = history.history['loss']
train_acc1 = history.history['accuracy']
xc1=range(len(train_acc1))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc1, train_acc1)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# lstm

# %%
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(LSTM(128))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 5
batch_size = 128

hist=model.fit(xt, yt, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 34s 160ms/step - loss: 0.5103 - accuracy: 0.7517
# Epoch 2/5
# 196/196 [==============================] - 24s 121ms/step - loss: 0.3932 - accuracy: 0.8401
# Epoch 3/5
# 196/196 [==============================] - 15s 79ms/step - loss: 0.2745 - accuracy: 0.8928
# Epoch 4/5
# 196/196 [==============================] - 11s 58ms/step - loss: 0.2296 - accuracy: 0.9125
# Epoch 5/5
# 196/196 [==============================] - 11s 53ms/step - loss: 0.2048 - accuracy: 0.9230

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 4s 13ms/step - loss: 0.3333 - accuracy: 0.8655
# accuracy: 0.8654800057411194
# loss: 0.3333103060722351

# %%
train_loss2 = hist.history['loss']
train_acc2 = hist.history['accuracy']
xc2=range(len(train_acc2))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc2, train_acc2)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# rnn

# %%
from tensorflow.keras.layers import Embedding,RNN
from keras import layers

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(layers.LSTM(128))
model.add(layers.Dense(10))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 7
batch_size = 128

h=model.fit(xt, yt, epochs=epochs, batch_size=batch_size, validation_split=0.2)
# Out:
# Epoch 1/7
# 157/157 [==============================] - 38s 222ms/step - loss: 0.4941 - accuracy: 0.7467 - val_loss: 0.3498 - val_accuracy: 0.8530
# Epoch 2/7
# 157/157 [==============================] - 19s 124ms/step - loss: 0.2738 - accuracy: 0.8903 - val_loss: 0.3415 - val_accuracy: 0.8594
# Epoch 3/7
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2292 - accuracy: 0.9137 - val_loss: 0.3580 - val_accuracy: 0.8392
# Epoch 4/7
# 157/157 [==============================] - 13s 80ms/step - loss: 0.1849 - accuracy: 0.9297 - val_loss: 0.3647 - val_accuracy: 0.8588
# Epoch 5/7
# 157/157 [==============================] - 10s 61ms/step - loss: 0.1426 - accuracy: 0.9470 - val_loss: 0.3798 - val_accuracy: 0.8562
# Epoch 6/7
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1057 - accuracy: 0.9633 - val_loss: 0.4493 - val_accuracy: 0.8480
# Epoch 7/7
# 157/157 [==============================] - 10s 64ms/step - loss: 0.0775 - accuracy: 0.9731 - val_loss: 0.6280 - val_accuracy: 0.8542

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 15ms/step - loss: 0.6603 - accuracy: 0.8486
# accuracy: 0.8485999703407288
# loss: 0.6602534651756287

# %%
train_loss3 = h.history['loss']
train_acc3 = h.history['accuracy']
xc3=range(len(train_loss3))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %%
plt.plot(xc1, train_acc1)
plt.plot(xc2, train_acc2)
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["GRU","LSTM","RNN"])
